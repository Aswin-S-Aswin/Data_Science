# %% [markdown]
# <a href="https://colab.research.google.com/github/Aswin-S-Aswin/Data_Science/blob/main/Data_Science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Libraries should be installed

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# ## Numeber Guessing Game Level 1

# %%
secret_num = 56

# %% [markdown]
# ### 1. Print if the user guessed number is right or not.

# %%
# user_input= int(input("Enter a number : "))

# if secret_num == user_input:
#   print("Congratulation! your guess is right!")
# else:
#   print("""Sorry. You guess is wrong""")

# %% [markdown]
# ### 2.Print if the user guessed number is right or not but with max of 7 trials.

# %%
# for i in range(7):
#   user_input= int(input(f"{i}. Enter a number : "))
#   if secret_num == user_input:
#     print("Congratulation! your guess is right!")
#     break
#   else:
#     print("Sorry. You guess is wrong")

# %% [markdown]
# #### Level 7 - Take this program to run as a function when it is called

# %%
import random

# print("Welcome to the Number Guessing Game!")
# print("I'm thinking of a number between 1 and 100")

# secret_num = random.randint(1,100)

# for i in range(8):
#   user_input= int(input(f"{i}. Enter a number : "))
#   if user_input < 1 or user_input > 100:
#     print("Invalid input. Please enter a number between 1 and 100.")
#   elif user_input > secret_num:
#     print("Too high")
#   elif user_input < secret_num:
#     print("Short broo")
#   else:
#     print("Congratulation! your guess is right!")
#     break

# if secret_num == user_input:
#   print("Super bro")
# else:
#   print("Ada Poda")
#   print(f"Output vantu : {secret_num}")

# %% [markdown]
# #### Level 6 - How to handle invalid characters

# %%
import random

# print("Welcome to the Number Guessing Game!")
# print("I'm thinking of a number between 1 and 100")

# secret_num = random.randint(1,100)

# for i in range(8):
#   try:
#     user_input= int(input(f"{i}. Enter a number : "))
#     if user_input < 1 or user_input > 100:
#       print("Invalid input. Please enter a number between 1 and 100.")
#     elif user_input > secret_num:
#       print("Too high")
#     elif user_input < secret_num:
#       print("Short broo")
#     else:
#       print("Congratulation! your guess is right!")
#       break
#   except ValueError:
#     print("Invalid input. Please enter a valid number.")

# if secret_num == user_input:
#   print("Super bro")
# else:
#   print("Ada Poda")
#   print(f"Output vantu : {secret_num}")

# %% [markdown]
# #### Level 7 - Run the program in the *function*

# %%
import random

# def number_guessing():

#   print("Welcome to the Number Guessing Game!")
#   print("I'm thinking of a number between 1 and 100")

#   secret_num = random.randint(1,100)
#   # print(secret_num)

#   for i in range(8):
#     try:
#       user_input= int(input(f"{i}. Enter a number : "))
#       if user_input < 1 or user_input > 100:
#         print("Invalid input. Please enter a number between 1 and 100.")
#       elif user_input > secret_num:
#         print("Too high")
#       elif user_input < secret_num:
#         print("Short broo")
#       else:
#         print("Congratulation! your guess is right!")
#         break
#     except ValueError:
#       print("Invalid input. Please enter a valid number.")

#   if secret_num == user_input:
#     print("Super bro")
#   else:
#     print("Ada Poda")
#     print(f"Output vantu : {secret_num}")

# %%
# number_guessing()

# %% [markdown]
# ### Will continue Later

# %%
import pandas as pd

# %%
a = pd.read_csv(filepath_or_buffer= r"./car_data.csv")
a
# Out:
#                         Model  Selling Price  Kilometers Driven  Year  \
# 0          MarutiWagonR1.0LXI         312165              82238  2014
# 1             ToyotaEtiosLiva         313799              30558  2013
# 2               MarutiAlto800         295999              22164  2018
# 3                 MarutiSwift         435199              30535  2013
# 4             MarutiWagonR1.0         289099              15738  2013
# ...                       ...            ...                ...   ...
# 2232          MarutiWagonR1.0         385999              45263  2015
# 2233              MarutiSwift         324099             100335  2012
# 2234              HyundaiEonD         212299              28016  2011
# 2235  FordEcosport1.5AMBIENTE         378899              87947  2013
# 2236            MarutiAltoK10         304299              33639  2015
#
#              Owner     Fuel Type Transmission   Insurance  Car Condition
# ...

# %% [markdown]
# ## 2. Numpy - Numerical Operations
#
# > Add blockquote

# %%
import numpy as np
import pandas as pd

a = pd.read_csv(filepath_or_buffer= r"/content/insurance.csv")

# %%
np.repeat(a,repeats=2,axis=0)
# Out:
# array([[19, 'female', 27.9, ..., 'yes', 'southwest', 16884.924],
#        [19, 'female', 27.9, ..., 'yes', 'southwest', 16884.924],
#        [18, 'male', 33.77, ..., 'no', 'southeast', 1725.5523],
#        ...,
#        [21, 'female', 25.8, ..., 'no', 'southwest', 2007.945],
#        [61, 'female', 29.07, ..., 'yes', 'northwest', 29141.3603],
#        [61, 'female', 29.07, ..., 'yes', 'northwest', 29141.3603]],
#       dtype=object)

# %%
pd.DataFrame(np.repeat(a,repeats=2,axis=0))
# Out:
#        0       1      2  3    4          5           6
# 0     19  female   27.9  0  yes  southwest   16884.924
# 1     19  female   27.9  0  yes  southwest   16884.924
# 2     18    male  33.77  1   no  southeast   1725.5523
# 3     18    male  33.77  1   no  southeast   1725.5523
# 4     28    male   33.0  3   no  southeast    4449.462
# ...   ..     ...    ... ..  ...        ...         ...
# 2671  18  female  36.85  0   no  southeast   1629.8335
# 2672  21  female   25.8  0   no  southwest    2007.945
# 2673  21  female   25.8  0   no  southwest    2007.945
# 2674  61  female  29.07  0  yes  northwest  29141.3603
# 2675  61  female  29.07  0  yes  northwest  29141.3603
#
# [2676 rows x 7 columns]

# %% [markdown]
# ## 3. Matplotlib,Seaborn and ploty

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
insurance_charge = pd.read_csv(filepath_or_buffer = '/content/insurance.csv')

# %%
# !python --version
a = pd.read_csv(filepath_or_buffer='/content/insurance.csv')
# Out:
# Python 3.12.13

# %%
plt.hist(a['charges'], bins=20)
# plt.xlabel('Selling Price')
# plt.ylabel('Frequency')
# plt.title('Histogram of Selling Price')
plt.show()

# %%
a.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %% [markdown]
# **Types of Datatypes**
#
# 1.Discrete - Countable, it will never have any units. You can't measure that
# 2.Continous - It will have units, it is measureable.

# %%
plt.hist(x = a.age, bins = None,histtype = 'step',color= 'red')
# Out:
# (array([222., 140., 109., 128., 102., 137., 144., 114., 128., 114.]),
#  array([18. , 22.6, 27.2, 31.8, 36.4, 41. , 45.6, 50.2, 54.8, 59.4, 64. ]),
#  [<matplotlib.patches.Polygon at 0x7c8d9cab9400>])

# %%
import seaborn as sns

# %%
sns.heatmap()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_901/3595583958.py in <cell line: 0>()
# ----> 1 sns.heatmap(a.corr(),annot=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11047         cols = data.columns
#   11048         idx = cols.copy()
# > 11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
#   11051         if method == "pearson":
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1991         if dtype is not None:
#    1992             dtype = np.dtype(dtype)
# -> 1993         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994         if result.dtype is not dtype:
#    1995             result = np.asarray(result, dtype=dtype)
#
# ...

# %%
import plotly.express as px
df = px.insurance_charge.gapminder().query("year == 2007").query("continent == 'Europe'")
df.loc[df['pop'] < 2.e6, 'country'] = 'Other countries' # Represent only large countries
fig = px.pie(df, values='pop', names='country', title='Population of European continent')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_901/1816294339.py in <cell line: 0>()
#       1 import plotly.express as px
# ----> 2 df = px.insurance_charge.gapminder().query("year == 2007").query("continent == 'Europe'")
#       3 df.loc[df['pop'] < 2.e6, 'country'] = 'Other countries' # Represent only large countries
#       4 fig = px.pie(df, values='pop', names='country', title='Population of European continent')
#       5 fig.show()
#
# AttributeError: module 'plotly.express' has no attribute 'insurance_charge'
